# %% [markdown]
# # 🚀 AIC2026 - Kaggle Offline Pipeline Runner (Multi-GPU 2x T4)
#
# Chạy toàn bộ pipeline xử lý offline nặng (Keyframe V2, CLIP Visual Index, YOLOE Object Detection, OCR Temporal V3, Faster-Whisper ASR V3) trên Kaggle GPU miễn phí.
#
# Sau khi hoàn thành, nén 7 file chỉ mục + ảnh Keyframe để tải về máy Local dùng với Backend FastAPI & React UI.

# %%
# 1. Setup Environment & Clone Repository (nếu cần)
import os
from pathlib import Path

REPO_DIR = Path("/kaggle/working/AIC2026_TeamPTK_SGU")
if not REPO_DIR.exists():
    # !git clone https://github.com/PTK-Team/AIC2026_TeamPTK_SGU.git /kaggle/working/AIC2026_TeamPTK_SGU

# %cd /kaggle/working/AIC2026_TeamPTK_SGU

# %% [markdown]
# ## 🧪 Smoke Test (Thử nghiệm 1 Video đầu tiên)

# %%
# 2. Chạy thử nghiệm trên 1 video (vd: L21_V001)
# !python kaggle/run_kaggle_master.py --smoke-test

# %% [markdown]
# ## 🔥 Run Full Pipeline (Xử lý toàn bộ Videos trên 2 GPU)

# %%
# 3. Chạy xử lý FULL toàn bộ Videos của BTC (tự động nhận 2 GPU T4)
# !python kaggle/run_kaggle_master.py --num-gpus 2

# %% [markdown]
# ## 📦 Kiểm tra File Output sẵn sàng Download

# %%
# 4. Kiểm tra các file zip sẵn sàng tải về máy local
# !ls -lh /kaggle/working/download/
